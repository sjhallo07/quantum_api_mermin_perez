# %% [markdown]
# # Matrix-variate Wishart workflow notebook
#
# This notebook reproduces the matrix-variate `Wishart` workflow described in the repo documentation.

# %%
import numpy as np
from pathlib import Path

# Matrix constants used by the repository workflow
MATRIZ_DENSIDAD_8X8 = np.array([
    [0.110, 0.030, 0.050, 0.020, 0.050, 0.040, 0.030, 0.030],
    [0.030, 0.130, 0.060, 0.020, 0.060, 0.050, 0.040, 0.040],
    [0.050, 0.060, 0.150, 0.030, 0.080, 0.060, 0.050, 0.050],
    [0.020, 0.020, 0.030, 0.100, 0.030, 0.030, 0.020, 0.020],
    [0.050, 0.060, 0.080, 0.030, 0.160, 0.060, 0.050, 0.050],
    [0.040, 0.050, 0.060, 0.030, 0.060, 0.120, 0.040, 0.040],
    [0.030, 0.040, 0.050, 0.020, 0.050, 0.040, 0.110, 0.030],
    [0.030, 0.040, 0.050, 0.020, 0.050, 0.040, 0.030, 0.120],
], dtype=float)

print("Matrix shape:", MATRIZ_DENSIDAD_8X8.shape)
print("Trace:", np.trace(MATRIZ_DENSIDAD_8X8))

# %% [markdown]
# ## Verification note
#
# This notebook is a lightweight proof-of-concept that mirrors the same matrix constants used by the Julia workflow.
